# %%
#step 0
#do the necesary imports that you need while you create the code
import numpy as np
import pandas as pd

# %%
#step 1
#create 2 dataframes
#read SPY500_descarga.csv from data folder

#read SPY500.csv
df = pd.read_csv('SPY500.csv'); df
# Out:
#     stocks
# 0      SPY
# 1        A
# 2      AAL
# 3      AAP
# 4     AAPL
# ..     ...
# 501    YUM
# 502    ZBH
# 503   ZBRA
# 504   ZION
# 505    ZTS
#
# [506 rows x 1 columns]

# %%
df_descarga= pd.read_csv('SPY500_descarga.csv'); df_descarga
# Out:
#      Unnamed: 0        Date         SPY           A        AAL         AAP  \
# 0             0  2019-12-26  322.940002   85.449997  29.670000  159.270004
# 1             1  2019-12-27  322.859985   85.419998  28.440001  158.350006
# 2             2  2019-12-30  321.079987   84.900002  28.299999  159.119995
# 3             3  2019-12-31  321.859985   85.309998  28.680000  160.160004
# 4             4  2020-01-02  324.869995   85.949997  29.090000  159.410004
# ..          ...         ...         ...         ...        ...         ...
# 499         499  2021-12-17  459.869995  151.419998  16.950001  232.820007
# 500         500  2021-12-20  454.980011  150.419998  17.299999  228.389999
# 501         501  2021-12-21  463.059998  153.960007  18.120001  229.570007
# 502         502  2021-12-22  467.690002  156.779999  18.260000  232.789993
# 503         503  2021-12-23  470.600006  157.800003  18.260000  232.130005
#
#            AAPL        ABBV         ABC        ABMD  ...        XEL  \
# 0     72.477501   89.830002   85.050003  171.009995  ...  62.790001
# 1     72.449997   89.199997   84.910004  169.270004  ...  63.119999
# 2     72.879997   88.519997   83.639999  167.289993  ...  63.290001
# 3     73.412498   88.540001   85.019997  170.589996  ...  63.490002
# 4     75.087502   89.550003   85.080002  168.809998  ...  62.380001
# ..          ...         ...         ...         ...  ...        ...
# 499  171.139999  129.529999  125.180000  315.549988  ...  67.000000
# 500  169.750000  130.860001  126.010002  316.230011  ...  67.120003
# 501  172.990005  129.949997  127.610001  332.200012  ...  66.339996
# 502  175.639999  132.050003  127.809998  343.399994  ...  66.730003
# 503  176.279999  133.089996  129.529999  352.209991  ...  66.610001
#
#            XLNX        XOM       XRAY         XYL         YUM         ZBH  \
# 0     98.680000  70.129997  56.529999   78.599998  101.790001  150.300003
# 1     98.419998  69.889999  56.840000   78.839996  101.900002  150.009995
# 2     97.680000  69.480003  56.400002   78.739998  100.639999  148.750000
# 3     97.769997  69.779999  56.590000   78.790001  100.730003  149.679993
# 4    101.650002  70.900002  56.930000   79.849998  102.169998  149.199997
# ..          ...        ...        ...         ...         ...         ...
# 499  200.139999  60.029999  53.410000  115.809998  131.929993  120.849998
# 500  196.149994  59.160000  52.590000  114.050003  131.570007  118.889999
# 501  206.429993  60.500000  52.970001  115.980003  133.369995  122.459999
# 502  215.000000  60.990002  54.389999  116.160004  134.630005  124.730003
# 503  216.110001  61.020000  55.430000  117.500000  135.339996  126.989998
#
#            ZBRA       ZION         ZTS
# 0    254.419998  51.660000  133.029999
# 1    256.000000  51.500000  133.250000
# 2    254.110001  51.770000  132.210007
# 3    255.440002  51.919998  132.350006
# 4    259.140015  52.439999  134.139999
# ..          ...        ...         ...
# 499  588.520020  61.200001  234.309998
# 500  570.780029  59.400002  234.259995
# 501  580.210022  61.650002  237.639999
# 502  580.429993  61.860001  241.570007
# 503  582.409973  62.360001  242.509995
#
# [504 rows x 506 columns]

# %%
#step 2
#create a list for stocks in data from SPY500.csv
stocks_list = df.stocks.unique();stocks_list
# Out:
# array(['SPY', 'A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABMD', 'ABT',
#        'ACN', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADSK', 'AEE', 'AEP', 'AES',
#        'AFL', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALGN', 'ALK', 'ALL',
#        'ALLE', 'AMAT', 'AMCR', 'AMD', 'AME', 'AMGN', 'AMP', 'AMT', 'AMZN',
#        'ANET', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'APD', 'APH', 'APTV',
#        'ARE', 'ATO', 'ATVI', 'AVB', 'AVGO', 'AVY', 'AWK', 'AXP', 'AZO',
#        'BA', 'BAC', 'BAX', 'BBWI', 'BBY', 'BDX', 'BEN', 'BF.B', 'BIIB',
#        'BIO', 'BK', 'BKNG', 'BKR', 'BLK', 'BLL', 'BMY', 'BR', 'BRK.B',
#        'BRO', 'BSX', 'BWA', 'BXP', 'C', 'CAG', 'CAH', 'CARR', 'CAT', 'CB',
#        'CBOE', 'CBRE', 'CCI', 'CCL', 'CDAY', 'CDNS', 'CDW', 'CE', 'CERN',
#        'CF', 'CFG', 'CHD', 'CHRW', 'CHTR', 'CI', 'CINF', 'CL', 'CLX',
#        'CMA', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF',
#        'COO', 'COP', 'COST', 'CPB', 'CPRT', 'CRL', 'CRM', 'CSCO', 'CSX',
#        'CTAS', 'CTLT', 'CTRA', 'CTSH', 'CTVA', 'CTXS', 'CVS', 'CVX',
#        'CZR', 'D', 'DAL', 'DD', 'DE', 'DFS', 'DG', 'DGX', 'DHI', 'DHR',
#        'DIS', 'DISCA', 'DISCK', 'DISH', 'DLR', 'DLTR', 'DOV', 'DOW',
#        'DPZ', 'DRE', 'DRI', 'DTE', 'DUK', 'DVA', 'DVN', 'DXC', 'DXCM',
#        'EA', 'EBAY', 'ECL', 'ED', 'EFX', 'EIX', 'EL', 'EMN', 'EMR',
#        'ENPH', 'EOG', 'EQIX', 'EQR', 'ES', 'ESS', 'ETN', 'ETR', 'ETSY',
#        'EVRG', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'F', 'FANG', 'FAST',
#        'FB', 'FBHS', 'FCX', 'FDX', 'FE', 'FFIV', 'FIS', 'FISV', 'FITB',
#        'FLT', 'FMC', 'FOX', 'FOXA', 'FRC', 'FRT', 'FTNT', 'FTV', 'GD',
#        'GE', 'GILD', 'GIS', 'GL', 'GLW', 'GM', 'GNRC', 'GOOG', 'GOOGL',
#        'GPC', 'GPN', 'GPS', 'GRMN', 'GS', 'GWW', 'HAL', 'HAS', 'HBAN',
#        'HBI', 'HCA', 'HD', 'HES', 'HIG', 'HII', 'HLT', 'HOLX', 'HON',
#        'HPE', 'HPQ', 'HRL', 'HSIC', 'HST', 'HSY', 'HUM', 'HWM', 'IBM',
#        'ICE', 'IDXX', 'IEX', 'IFF', 'ILMN', 'INCY', 'INFO', 'INTC',
#        'INTU', 'IP', 'IPG', 'IPGP', 'IQV', 'IR', 'IRM', 'ISRG', 'IT',
#        'ITW', 'IVZ', 'J', 'JBHT', 'JCI', 'JKHY', 'JNJ', 'JNPR', 'JPM',
#        'K', 'KEY', 'KEYS', 'KHC', 'KIM', 'KLAC', 'KMB', 'KMI', 'KMX',
#        'KO', 'KR', 'KSU', 'L', 'LDOS', 'LEG', 'LEN', 'LH', 'LHX', 'LIN',
#        'LKQ', 'LLY', 'LMT', 'LNC', 'LNT', 'LOW', 'LRCX', 'LUMN', 'LUV',
#        'LVS', 'LW', 'LYB', 'LYV', 'MA', 'MAA', 'MAR', 'MAS', 'MCD',
#        'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDT', 'MET', 'MGM', 'MHK', 'MKC',
#        'MKTX', 'MLM', 'MMC', 'MMM', 'MNST', 'MO', 'MOS', 'MPC', 'MPWR',
#        'MRK', 'MRNA', 'MRO', 'MS', 'MSCI', 'MSFT', 'MSI', 'MTB', 'MTCH',
#        'MTD', 'MU', 'NCLH', 'NDAQ', 'NEE', 'NEM', 'NFLX', 'NI', 'NKE',
#        'NLOK', 'NLSN', 'NOC', 'NOW', 'NRG', 'NSC', 'NTAP', 'NTRS', 'NUE',
#        'NVDA', 'NVR', 'NWL', 'NWS', 'NWSA', 'NXPI', 'O', 'ODFL', 'OGN',
#        'OKE', 'OMC', 'ORCL', 'ORLY', 'OTIS', 'OXY', 'PAYC', 'PAYX',
#        'PBCT', 'PCAR', 'PEAK', 'PEG', 'PENN', 'PEP', 'PFE', 'PFG', 'PG',
#        'PGR', 'PH', 'PHM', 'PKG', 'PKI', 'PLD', 'PM', 'PNC', 'PNR', 'PNW',
#        'POOL', 'PPG', 'PPL', 'PRU', 'PSA', 'PSX', 'PTC', 'PVH', 'PWR',
#        'PXD', 'PYPL', 'QCOM', 'QRVO', 'RCL', 'RE', 'REG', 'REGN', 'RF',
#        'RHI', 'RJF', 'RL', 'RMD', 'ROK', 'ROL', 'ROP', 'ROST', 'RSG',
#        'RTX', 'SBAC', 'SBUX', 'SCHW', 'SEE', 'SHW', 'SIVB', 'SJM', 'SLB',
#        'SNA', 'SNPS', 'SO', 'SPG', 'SPGI', 'SRE', 'STE', 'STT', 'STX',
#        'STZ', 'SWK', 'SWKS', 'SYF', 'SYK', 'SYY', 'T', 'TAP', 'TDG',
#        'TDY', 'TECH', 'TEL', 'TER', 'TFC', 'TFX', 'TGT', 'TJX', 'TMO',
#        'TMUS', 'TPR', 'TRMB', 'TROW', 'TRV', 'TSCO', 'TSLA', 'TSN', 'TT',
#        'TTWO', 'TWTR', 'TXN', 'TXT', 'TYL', 'UA', 'UAA', 'UAL', 'UDR',
#        'UHS', 'ULTA', 'UNH', 'UNP', 'UPS', 'URI', 'USB', 'V', 'VFC',
#        'VIAC', 'VLO', 'VMC', 'VNO', 'VRSK', 'VRSN', 'VRTX', 'VTR', 'VTRS',
#        'VZ', 'WAB', 'WAT', 'WBA', 'WDC', 'WEC', 'WELL', 'WFC', 'WHR',
#        'WLTW', 'WM', 'WMB', 'WMT', 'WRB', 'WRK', 'WST', 'WU', 'WY',
#        'WYNN', 'XEL', 'XLNX', 'XOM', 'XRAY', 'XYL', 'YUM', 'ZBH', 'ZBRA',
#        'ZION', 'ZTS'], dtype=object)

# %%
stocks_list[:5]
# Out:
# array(['SPY', 'A', 'AAL', 'AAP', 'AAPL'], dtype=object)

# %%
stocks_list[-5:]
# Out:
# array(['YUM', 'ZBH', 'ZBRA', 'ZION', 'ZTS'], dtype=object)

# %% [markdown]
# # top 5 and bottom 5 list must look like this
# > ['SPY', 'A', 'AAL', 'AAP', 'AAPL'] **this is the top**.
#
# > ['YUM', 'ZBH', 'ZBRA', 'ZION', 'ZTS'] **this is the tail**.

# %%
#step 3
#remove Unnamed: 0 column
#Sort index acending = False dataframe from SPY500_descarga

# %%
df_descarga = df_descarga.drop(["Unnamed: 0"], axis=1)

# %%
df_descarga
# Out:
#            Date         SPY           A        AAL         AAP        AAPL  \
# 0    2019-12-26  322.940002   85.449997  29.670000  159.270004   72.477501
# 1    2019-12-27  322.859985   85.419998  28.440001  158.350006   72.449997
# 2    2019-12-30  321.079987   84.900002  28.299999  159.119995   72.879997
# 3    2019-12-31  321.859985   85.309998  28.680000  160.160004   73.412498
# 4    2020-01-02  324.869995   85.949997  29.090000  159.410004   75.087502
# ..          ...         ...         ...        ...         ...         ...
# 499  2021-12-17  459.869995  151.419998  16.950001  232.820007  171.139999
# 500  2021-12-20  454.980011  150.419998  17.299999  228.389999  169.750000
# 501  2021-12-21  463.059998  153.960007  18.120001  229.570007  172.990005
# 502  2021-12-22  467.690002  156.779999  18.260000  232.789993  175.639999
# 503  2021-12-23  470.600006  157.800003  18.260000  232.130005  176.279999
#
#            ABBV         ABC        ABMD         ABT  ...        XEL  \
# 0     89.830002   85.050003  171.009995   87.279999  ...  62.790001
# 1     89.199997   84.910004  169.270004   87.400002  ...  63.119999
# 2     88.519997   83.639999  167.289993   86.800003  ...  63.290001
# 3     88.540001   85.019997  170.589996   86.860001  ...  63.490002
# | 2021-12-21 | 463.06 | 153.96 | 18.12 | 229.57 | 172.99 |
# | 2021-12-20 | 454.98 | 150.42 | 17.3  | 228.39 | 169.75 |
# | 2021-12-17 | 459.87 | 151.42 | 16.95 | 232.82 | 171.14 |
# | 2021-12-16 | 466.45 | 150.8  | 16.52 | 239.16 | 172.26 |
# | 2021-12-15 | 470.6  | 154.31 | 16.99 | 239.14 | 179.3  |
# | 2021-12-14 | 463.36 | 151.88 | 16.91 | 235.39 | 174.33 |
# | 2021-12-13 | 466.57 | 156.29 | 17.12 | 234.12 | 175.74 |
# | 2021-12-10 | 470.74 | 156.26 | 18.01 | 240.04 | 179.45 |

# %%
#step 6
#Create a diccionary  with name random_dic  like this {number : column, number: column ,....}

#hint ---some SPY500 data is missing because some stocks does not have 2 year period or i coulndt download because API Fails 
#        or they are delisted from the market

# %%
list_r = list (range(len(stocks_list)))
random_dic = dict(zip(list_r, stocks_list) );random_dic
# Out:
# {0: 'SPY',
#  1: 'A',
#  2: 'AAL',
#  3: 'AAP',
#  4: 'AAPL',
#  5: 'ABBV',
#  6: 'ABC',
#  7: 'ABMD',
#  8: 'ABT',
#  9: 'ACN',
#  10: 'ADBE',
#  11: 'ADI',
#  12: 'ADM',
#  13: 'ADP',
#  14: 'ADSK',
#  15: 'AEE',
#  16: 'AEP',
#  17: 'AES',
#  18: 'AFL',
#  19: 'AIG',
#  20: 'AIZ',
#  21: 'AJG',
#  22: 'AKAM',
#  23: 'ALB',
#  24: 'ALGN',
#  25: 'ALK',
#  26: 'ALL',
#  27: 'ALLE',
#  28: 'AMAT',
#  29: 'AMCR',
#  30: 'AMD',
#  31: 'AME',
#  32: 'AMGN',
#  33: 'AMP',
#  34: 'AMT',
#  35: 'AMZN',
#  36: 'ANET',
#  37: 'ANSS',
#  38: 'ANTM',
#  39: 'AON',
#  40: 'AOS',
#  41: 'APA',
#  42: 'APD',
#  43: 'APH',
#  44: 'APTV',
#  45: 'ARE',
#  46: 'ATO',
#  47: 'ATVI',
#  48: 'AVB',
#  49: 'AVGO',
#  50: 'AVY',
#  51: 'AWK',
#  52: 'AXP',
#  53: 'AZO',
#  54: 'BA',
#  55: 'BAC',
#  56: 'BAX',
#  57: 'BBWI',
#  58: 'BBY',
#  59: 'BDX',
#  60: 'BEN',
#  61: 'BF.B',
#  62: 'BIIB',
#  63: 'BIO',
#  64: 'BK',
#  65: 'BKNG',
#  66: 'BKR',
#  67: 'BLK',
#  68: 'BLL',
#  69: 'BMY',
#  70: 'BR',
#  71: 'BRK.B',
#  72: 'BRO',
#  73: 'BSX',
#  74: 'BWA',
#  75: 'BXP',
#  76: 'C',
#  77: 'CAG',
#  78: 'CAH',
#  79: 'CARR',
#  80: 'CAT',
#  81: 'CB',
#  82: 'CBOE',
#  83: 'CBRE',
#  84: 'CCI',
#  85: 'CCL',
#  86: 'CDAY',
#  87: 'CDNS',
#  88: 'CDW',
#  89: 'CE',
#  90: 'CERN',
#  91: 'CF',
#  92: 'CFG',
#  93: 'CHD',
#  94: 'CHRW',
#  95: 'CHTR',
#  96: 'CI',
#  97: 'CINF',
#  98: 'CL',
#  99: 'CLX',
#  100: 'CMA',
#  101: 'CMCSA',
#  102: 'CME',
#  103: 'CMG',
#  104: 'CMI',
#  105: 'CMS',
#  106: 'CNC',
#  107: 'CNP',
#  108: 'COF',
#  109: 'COO',
#  110: 'COP',
#  111: 'COST',
#  112: 'CPB',
#  113: 'CPRT',
#  114: 'CRL',
#  115: 'CRM',
#  116: 'CSCO',
#  117: 'CSX',
#  118: 'CTAS',
#  119: 'CTLT',
#  120: 'CTRA',
#  121: 'CTSH',
#  122: 'CTVA',
#  123: 'CTXS',
#  124: 'CVS',
#  125: 'CVX',
#  126: 'CZR',
#  127: 'D',
#  128: 'DAL',
#  129: 'DD',
#  130: 'DE',
#  131: 'DFS',
#  132: 'DG',
#  133: 'DGX',
#  134: 'DHI',
#  135: 'DHR',
#  136: 'DIS',
#  137: 'DISCA',
#  138: 'DISCK',
#  139: 'DISH',
#  140: 'DLR',
#  141: 'DLTR',
#  142: 'DOV',
#  143: 'DOW',
#  144: 'DPZ',
#  145: 'DRE',
#  146: 'DRI',
#  147: 'DTE',
#  148: 'DUK',
#  149: 'DVA',
#  150: 'DVN',
#  151: 'DXC',
#  152: 'DXCM',
#  153: 'EA',
#  154: 'EBAY',
#  155: 'ECL',
#  156: 'ED',
#  157: 'EFX',
#  158: 'EIX',
#  159: 'EL',
#  160: 'EMN',
#  161: 'EMR',
#  162: 'ENPH',
#  163: 'EOG',
#  164: 'EQIX',
#  165: 'EQR',
#  166: 'ES',
#  167: 'ESS',
#  168: 'ETN',
#  169: 'ETR',
#  170: 'ETSY',
#  171: 'EVRG',
#  172: 'EW',
#  173: 'EXC',
#  174: 'EXPD',
#  175: 'EXPE',
#  176: 'EXR',
#  177: 'F',
#  178: 'FANG',
#  179: 'FAST',
#  180: 'FB',
#  181: 'FBHS',
#  182: 'FCX',
#  183: 'FDX',
#  184: 'FE',
#  185: 'FFIV',
#  186: 'FIS',
#  187: 'FISV',
#  188: 'FITB',
#  189: 'FLT',
#  190: 'FMC',
#  191: 'FOX',
#  192: 'FOXA',
#  193: 'FRC',
#  194: 'FRT',
#  195: 'FTNT',
#  196: 'FTV',
#  197: 'GD',
#  198: 'GE',
#  199: 'GILD',
#  200: 'GIS',
#  201: 'GL',
#  202: 'GLW',
#  203: 'GM',
#  204: 'GNRC',
#  205: 'GOOG',
#  206: 'GOOGL',
#  207: 'GPC',
#  208: 'GPN',
#  209: 'GPS',
#  210: 'GRMN',
#  211: 'GS',
#  212: 'GWW',
#  213: 'HAL',
#  214: 'HAS',
#  215: 'HBAN',
#  216: 'HBI',
#  217: 'HCA',
#  218: 'HD',
#  219: 'HES',
#  220: 'HIG',
#  221: 'HII',
#  222: 'HLT',
#  223: 'HOLX',
#  224: 'HON',
#  225: 'HPE',
#  226: 'HPQ',
#  227: 'HRL',
#  228: 'HSIC',
#  229: 'HST',
#  230: 'HSY',
#  231: 'HUM',
#  232: 'HWM',
#  233: 'IBM',
#  234: 'ICE',
#  235: 'IDXX',
#  236: 'IEX',
#  237: 'IFF',
#  238: 'ILMN',
#  239: 'INCY',
#  240: 'INFO',
#  241: 'INTC',
#  242: 'INTU',
#  243: 'IP',
#  244: 'IPG',
#  245: 'IPGP',
#  246: 'IQV',
#  247: 'IR',
#  248: 'IRM',
#  249: 'ISRG',
#  250: 'IT',
#  251: 'ITW',
#  252: 'IVZ',
#  253: 'J',
#  254: 'JBHT',
#  255: 'JCI',
#  256: 'JKHY',
#  257: 'JNJ',
#  258: 'JNPR',
#  259: 'JPM',
#  260: 'K',
#  261: 'KEY',
#  262: 'KEYS',
#  263: 'KHC',
#  264: 'KIM',
#  265: 'KLAC',
#  266: 'KMB',
#  267: 'KMI',
#  268: 'KMX',
#  269: 'KO',
#  270: 'KR',
#  271: 'KSU',
#  272: 'L',
#  273: 'LDOS',
#  274: 'LEG',
#  275: 'LEN',
#  276: 'LH',
#  277: 'LHX',
#  278: 'LIN',
#  279: 'LKQ',
#  280: 'LLY',
#  281: 'LMT',
#  282: 'LNC',
#  283: 'LNT',
#  284: 'LOW',
#  285: 'LRCX',
#  286: 'LUMN',
#  287: 'LUV',
#  288: 'LVS',
#  289: 'LW',
#  290: 'LYB',
#  291: 'LYV',
#  292: 'MA',
#  293: 'MAA',
#  294: 'MAR',
#  295: 'MAS',
#  296: 'MCD',
#  297: 'MCHP',
#  298: 'MCK',
#  299: 'MCO',
#  300: 'MDLZ',
#  301: 'MDT',
#  302: 'MET',
#  303: 'MGM',
#  304: 'MHK',
#  305: 'MKC',
#  306: 'MKTX',
#  307: 'MLM',
#  308: 'MMC',
#  309: 'MMM',
#  310: 'MNST',
#  311: 'MO',
#  312: 'MOS',
#  313: 'MPC',
#  314: 'MPWR',
#  315: 'MRK',
#  316: 'MRNA',
#  317: 'MRO',
#  318: 'MS',
#  319: 'MSCI',
#  320: 'MSFT',
#  321: 'MSI',
#  322: 'MTB',
#  323: 'MTCH',
#  324: 'MTD',
#  325: 'MU',
#  326: 'NCLH',
#  327: 'NDAQ',
#  328: 'NEE',
#  329: 'NEM',
#  330: 'NFLX',
#  331: 'NI',
#  332: 'NKE',
#  333: 'NLOK',
#  334: 'NLSN',
#  335: 'NOC',
#  336: 'NOW',
#  337: 'NRG',
#  338: 'NSC',
#  339: 'NTAP',
#  340: 'NTRS',
#  341: 'NUE',
#  342: 'NVDA',
#  343: 'NVR',
#  344: 'NWL',
#  345: 'NWS',
#  346: 'NWSA',
#  347: 'NXPI',
#  348: 'O',
#  349: 'ODFL',
#  350: 'OGN',
#  351: 'OKE',
#  352: 'OMC',
#  353: 'ORCL',
#  354: 'ORLY',
#  355: 'OTIS',
#  356: 'OXY',
#  357: 'PAYC',
#  358: 'PAYX',
#  359: 'PBCT',
#  360: 'PCAR',
#  361: 'PEAK',
#  362: 'PEG',
#  363: 'PENN',
#  364: 'PEP',
#  365: 'PFE',
#  366: 'PFG',
#  367: 'PG',
#  368: 'PGR',
#  369: 'PH',
#  370: 'PHM',
#  371: 'PKG',
#  372: 'PKI',
#  373: 'PLD',
#  374: 'PM',
#  375: 'PNC',
#  376: 'PNR',
#  377: 'PNW',
#  378: 'POOL',
#  379: 'PPG',
#  380: 'PPL',
#  381: 'PRU',
#  382: 'PSA',
#  383: 'PSX',
#  384: 'PTC',
#  385: 'PVH',
#  386: 'PWR',
#  387: 'PXD',
#  388: 'PYPL',
#  389: 'QCOM',
#  390: 'QRVO',
#  391: 'RCL',
#  392: 'RE',
#  393: 'REG',
#  394: 'REGN',
#  395: 'RF',
#  396: 'RHI',
#  397: 'RJF',
#  398: 'RL',
#  399: 'RMD',
#  400: 'ROK',
#  401: 'ROL',
#  402: 'ROP',
#  403: 'ROST',
#  404: 'RSG',
#  405: 'RTX',
#  406: 'SBAC',
#  407: 'SBUX',
#  408: 'SCHW',
#  409: 'SEE',
#  410: 'SHW',
#  411: 'SIVB',
#  412: 'SJM',
#  413: 'SLB',
#  414: 'SNA',
#  415: 'SNPS',
#  416: 'SO',
#  417: 'SPG',
#  418: 'SPGI',
#  419: 'SRE',
#  420: 'STE',
#  421: 'STT',
#  422: 'STX',
#  423: 'STZ',
#  424: 'SWK',
#  425: 'SWKS',
#  426: 'SYF',
#  427: 'SYK',
#  428: 'SYY',
#  429: 'T',
#  430: 'TAP',
#  431: 'TDG',
#  432: 'TDY',
#  433: 'TECH',
#  434: 'TEL',
#  435: 'TER',
#  436: 'TFC',
#  437: 'TFX',
#  438: 'TGT',
#  439: 'TJX',
#  440: 'TMO',
#  441: 'TMUS',
#  442: 'TPR',
#  443: 'TRMB',
#  444: 'TROW',
#  445: 'TRV',
#  446: 'TSCO',
#  447: 'TSLA',
#  448: 'TSN',
#  449: 'TT',
#  450: 'TTWO',
#  451: 'TWTR',
#  452: 'TXN',
#  453: 'TXT',
#  454: 'TYL',
#  455: 'UA',
#  456: 'UAA',
#  457: 'UAL',
#  458: 'UDR',
#  459: 'UHS',
#  460: 'ULTA',
#  461: 'UNH',
#  462: 'UNP',
#  463: 'UPS',
#  464: 'URI',
#  465: 'USB',
#  466: 'V',
#  467: 'VFC',
#  468: 'VIAC',
#  469: 'VLO',
#  470: 'VMC',
#  471: 'VNO',
#  472: 'VRSK',
#  473: 'VRSN',
#  474: 'VRTX',
#  475: 'VTR',
#  476: 'VTRS',
#  477: 'VZ',
#  478: 'WAB',
#  479: 'WAT',
#  480: 'WBA',
#  481: 'WDC',
#  482: 'WEC',
#  483: 'WELL',
#  484: 'WFC',
#  485: 'WHR',
#  486: 'WLTW',
#  487: 'WM',
#  488: 'WMB',
#  489: 'WMT',
#  490: 'WRB',
#  491: 'WRK',
#  492: 'WST',
#  493: 'WU',
#  494: 'WY',
#  495: 'WYNN',
#  496: 'XEL',
#  497: 'XLNX',
#  498: 'XOM',
#  499: 'XRAY',
#  500: 'XYL',
#  501: 'YUM',
#  502: 'ZBH',
#  503: 'ZBRA',
#  504: 'ZION',
#  505: 'ZTS'}

# %% [markdown]
# # dictionary must look like this
# {0: 'SPY', 1: 'A', 2: 'AAL', 3: 'AAP', 4: 'AAPL', 5: 'ABBV', 6: 'ABC',....}

# %%
df_descarga.columns
# Out:
# Index(['SPY', 'A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABMD', 'ABT', 'ACN',
#        ...
#        'XEL', 'XLNX', 'XOM', 'XRAY', 'XYL', 'YUM', 'ZBH', 'ZBRA', 'ZION',
#        'ZTS'],
#       dtype='object', length=504)

# %%
stocks_list
# Out:
# array(['SPY', 'A', 'AAL', 'AAP', 'AAPL', 'ABBV', 'ABC', 'ABMD', 'ABT',
#        'ACN', 'ADBE', 'ADI', 'ADM', 'ADP', 'ADSK', 'AEE', 'AEP', 'AES',
#        'AFL', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALGN', 'ALK', 'ALL',
#        'ALLE', 'AMAT', 'AMCR', 'AMD', 'AME', 'AMGN', 'AMP', 'AMT', 'AMZN',
#        'ANET', 'ANSS', 'ANTM', 'AON', 'AOS', 'APA', 'APD', 'APH', 'APTV',
#        'ARE', 'ATO', 'ATVI', 'AVB', 'AVGO', 'AVY', 'AWK', 'AXP', 'AZO',
#        'BA', 'BAC', 'BAX', 'BBWI', 'BBY', 'BDX', 'BEN', 'BF.B', 'BIIB',
#        'BIO', 'BK', 'BKNG', 'BKR', 'BLK', 'BLL', 'BMY', 'BR', 'BRK.B',
#        'BRO', 'BSX', 'BWA', 'BXP', 'C', 'CAG', 'CAH', 'CARR', 'CAT', 'CB',
#        'CBOE', 'CBRE', 'CCI', 'CCL', 'CDAY', 'CDNS', 'CDW', 'CE', 'CERN',
#        'CF', 'CFG', 'CHD', 'CHRW', 'CHTR', 'CI', 'CINF', 'CL', 'CLX',
#        'CMA', 'CMCSA', 'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF',
#        'COO', 'COP', 'COST', 'CPB', 'CPRT', 'CRL', 'CRM', 'CSCO', 'CSX',
#        'CTAS', 'CTLT', 'CTRA', 'CTSH', 'CTVA', 'CTXS', 'CVS', 'CVX',
#        'CZR', 'D', 'DAL', 'DD', 'DE', 'DFS', 'DG', 'DGX', 'DHI', 'DHR',
#        'DIS', 'DISCA', 'DISCK', 'DISH', 'DLR', 'DLTR', 'DOV', 'DOW',
#        'DPZ', 'DRE', 'DRI', 'DTE', 'DUK', 'DVA', 'DVN', 'DXC', 'DXCM',
#        'EA', 'EBAY', 'ECL', 'ED', 'EFX', 'EIX', 'EL', 'EMN', 'EMR',
#        'ENPH', 'EOG', 'EQIX', 'EQR', 'ES', 'ESS', 'ETN', 'ETR', 'ETSY',
#        'EVRG', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'F', 'FANG', 'FAST',
#        'FB', 'FBHS', 'FCX', 'FDX', 'FE', 'FFIV', 'FIS', 'FISV', 'FITB',
#        'FLT', 'FMC', 'FOX', 'FOXA', 'FRC', 'FRT', 'FTNT', 'FTV', 'GD',
#        'GE', 'GILD', 'GIS', 'GL', 'GLW', 'GM', 'GNRC', 'GOOG', 'GOOGL',
#        'GPC', 'GPN', 'GPS', 'GRMN', 'GS', 'GWW', 'HAL', 'HAS', 'HBAN',
#        'HBI', 'HCA', 'HD', 'HES', 'HIG', 'HII', 'HLT', 'HOLX', 'HON',
#        'HPE', 'HPQ', 'HRL', 'HSIC', 'HST', 'HSY', 'HUM', 'HWM', 'IBM',
#        'ICE', 'IDXX', 'IEX', 'IFF', 'ILMN', 'INCY', 'INFO', 'INTC',
#        'INTU', 'IP', 'IPG', 'IPGP', 'IQV', 'IR', 'IRM', 'ISRG', 'IT',
#        'ITW', 'IVZ', 'J', 'JBHT', 'JCI', 'JKHY', 'JNJ', 'JNPR', 'JPM',
#        'K', 'KEY', 'KEYS', 'KHC', 'KIM', 'KLAC', 'KMB', 'KMI', 'KMX',
#        'KO', 'KR', 'KSU', 'L', 'LDOS', 'LEG', 'LEN', 'LH', 'LHX', 'LIN',
#        'LKQ', 'LLY', 'LMT', 'LNC', 'LNT', 'LOW', 'LRCX', 'LUMN', 'LUV',
#        'LVS', 'LW', 'LYB', 'LYV', 'MA', 'MAA', 'MAR', 'MAS', 'MCD',
#        'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDT', 'MET', 'MGM', 'MHK', 'MKC',
#        'MKTX', 'MLM', 'MMC', 'MMM', 'MNST', 'MO', 'MOS', 'MPC', 'MPWR',
#        'MRK', 'MRNA', 'MRO', 'MS', 'MSCI', 'MSFT', 'MSI', 'MTB', 'MTCH',
#        'MTD', 'MU', 'NCLH', 'NDAQ', 'NEE', 'NEM', 'NFLX', 'NI', 'NKE',
#        'NLOK', 'NLSN', 'NOC', 'NOW', 'NRG', 'NSC', 'NTAP', 'NTRS', 'NUE',
#        'NVDA', 'NVR', 'NWL', 'NWS', 'NWSA', 'NXPI', 'O', 'ODFL', 'OGN',
#        'OKE', 'OMC', 'ORCL', 'ORLY', 'OTIS', 'OXY', 'PAYC', 'PAYX',
#        'PBCT', 'PCAR', 'PEAK', 'PEG', 'PENN', 'PEP', 'PFE', 'PFG', 'PG',
#        'PGR', 'PH', 'PHM', 'PKG', 'PKI', 'PLD', 'PM', 'PNC', 'PNR', 'PNW',
#        'POOL', 'PPG', 'PPL', 'PRU', 'PSA', 'PSX', 'PTC', 'PVH', 'PWR',
#        'PXD', 'PYPL', 'QCOM', 'QRVO', 'RCL', 'RE', 'REG', 'REGN', 'RF',
#        'RHI', 'RJF', 'RL', 'RMD', 'ROK', 'ROL', 'ROP', 'ROST', 'RSG',
#        'RTX', 'SBAC', 'SBUX', 'SCHW', 'SEE', 'SHW', 'SIVB', 'SJM', 'SLB',
#        'SNA', 'SNPS', 'SO', 'SPG', 'SPGI', 'SRE', 'STE', 'STT', 'STX',
#        'STZ', 'SWK', 'SWKS', 'SYF', 'SYK', 'SYY', 'T', 'TAP', 'TDG',
#        'TDY', 'TECH', 'TEL', 'TER', 'TFC', 'TFX', 'TGT', 'TJX', 'TMO',
#        'TMUS', 'TPR', 'TRMB', 'TROW', 'TRV', 'TSCO', 'TSLA', 'TSN', 'TT',
#        'TTWO', 'TWTR', 'TXN', 'TXT', 'TYL', 'UA', 'UAA', 'UAL', 'UDR',
#        'UHS', 'ULTA', 'UNH', 'UNP', 'UPS', 'URI', 'USB', 'V', 'VFC',
#        'VIAC', 'VLO', 'VMC', 'VNO', 'VRSK', 'VRSN', 'VRTX', 'VTR', 'VTRS',
#        'VZ', 'WAB', 'WAT', 'WBA', 'WDC', 'WEC', 'WELL', 'WFC', 'WHR',
#        'WLTW', 'WM', 'WMB', 'WMT', 'WRB', 'WRK', 'WST', 'WU', 'WY',
#        'WYNN', 'XEL', 'XLNX', 'XOM', 'XRAY', 'XYL', 'YUM', 'ZBH', 'ZBRA',
#        'ZION', 'ZTS'], dtype=object)

# %%
mask_missing_cols = np.isin (stocks_list, df_descarga.columns)
list_index_missing_cols = [x for x in range(len(mask_missing_cols)) if mask_missing_cols[x] == False]
list_index_missing_cols
# Out:
# [61, 71]

# %%
mask_invert = np.isin (stocks_list, df_descarga.columns, invert = True)
stocks_list[mask_inv]
# Out:
# array(['BF.B', 'BRK.B'], dtype=object)

# %%
# Out:
# BF.B .... Falta
# BRK.B .... Falta
# CARR .... Datos no completos
# KSU .... Datos no completos
# OGN .... Datos no completos
# OTIS .... Datos no completos
# Se removieron:  6 columnas

# %%
#step 7


#Manage missing data of your dataframe in the way you want

#hint ---- Remember to update your list from step 2.
#hint ---- Some companies of stocks actualy have less than 2 years of data because they have less than 2 year of existance in the market
#          if you make a mean of the data you will be manipulating the numbers and its a investment descition
#          arround 1 billion dollars will be managed by this analysis so think the analysis only works well with arround 2 years of data.
#          if you make a mistake people may will lose their job and their life savings.
#          take a decisiton and explain why you take it.
stocks_list_update = list(stocks_list)

for i in range(len(mask_invert)):
    if mask_invert[i]:
        print (stocks_list[i], ".... Falta")
        stocks_list_update.remove(stocks_list[i])
        
        

for col in df_descarga.columns:
    if df_descarga.loc[:,col].count() !=504:
        print (col, ".... Datos no completos")
        stocks_list_update.remove(col)
        df_descarga= df_descarga.drop([col], axis=1)
    
print ('Se removieron: ', len(stocks_list) -len(stocks_list_update), 'columnas')
# Out:
# BF.B .... Falta
# BRK.B .... Falta
# CARR .... Datos no completos
# KSU .... Datos no completos
# OGN .... Datos no completos
# OTIS .... Datos no completos
# Se removieron:  6 columnas

# %%
len(df_descarga.columns)
# Out:
# 500

# %%
#step 8
#Explain your decisition of how you managed the missing data

# %%
#step 9
#We are going to plot some data in orde to see if they have some logic that we can apply it, lets explore it
#Create a list or a function that get 9 random numbers with the max number as the  max lenght of your stock list updated.
#The first in the list must by the number corresponding to SPY allways
random_numbers = [np.random.randint(0,len(stocks_list_update)) for i in range(9+1) ]
random_numbers[0] = 0
index_max = random_numbers.index (max (random_numbers))
random_numbers[index_max] = len(stocks_list_update)
random_numbers
# Out:
# [0, 257, 118, 109, 186, 500, 360, 39, 3, 59]

# %% [markdown]
# # No Mater how much i run it it allways give 0 cause the first item in the list
# [0, 479, 14, 404, 272, 94, 261, 316, 63]
#
# [0, 446, 176, 419, 116, 278, 417, 459, 284]
#
# [0, 239, 367, 403, 449, 274, 382, 335, 15]
#
# [0, 373, 466, 321, 93, 185, 107, 422, 256]

# %%
#step 10
#Create a figure  3 columns and 3 rows and plot a histogram random stocks on it,
#each graph must have the name of the stock 
import matplotlib.pyplot as plt
# %matplotlib inline

fig, axs = plt.subplots(3,3, figsize = (8, 8))
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', 
     '#d62728', '#9467bd', '#8c564b', 
     '#e377c2', '#7f7f7f','#bcbd22']
for i, ax in enumerate(axs.flatten()):
    icol = random_numbers[i]    
    ax.hist(df_descarga.iloc[:, icol], color = colors[i])
    ax.set_title(random_dic_update.get (icol))
    ax.set_xlabel('price')
    ax.set_ylabel('counts')
fig.tight_layout()


#print your list of the stocks
#print(stocks_list_update)

#hint --- you can use random from numpy and use the dictionary  and the function or list we have made to select the information 
#         from your dataframe
#hint --- SPY is an index of 500 stocks that means it has a partial number of percentage of each stock is in your data, its your brenchmark

# %%
from IPython.display import Image
Image(filename='image.png')
#your output and graph must be something like this because its random except SPY stock at position 0,0

# %%
# Step 11
#save your Dataframe as Csv or picke las Cleaned_SPY500.csv or Cleaned_SPY500.pkl
df_descarga.to_csv('Cleaned_SPY500.csv')

# %%
# Step 12 answer some questions about the data


#1.-what does the data is telling you?
#Hay más Stock con precios menores respecto a la referencia SPY.  

#2.-the prices are close to the same range? why or why not?
#No, los rangos de precio son distintos en cada stock. 
#No se observa un comportamiento constante en la dristribucion de estos, en los diferentes Stocks

#3.-how i can know if a specific stock is following or not the brenchmark?
#Si sus curvas tuvieran una misma distribucion (misma forma de la curva)

#4.-how i can compare 2 diferent stocks of diferent prices?
#Normalizando los precios en cada stock

# %%
# Step 13
# CREATE A DATAFRAME  with 10 stocks you pick as top stocks based in youe feelings and information you know or select it randomly
# first column your name, second column the ticker of the stock
my_df_stocks = pd.DataFrame (
    {
       'stocks': list(random_dic_update.get (i) for i in random_numbers),
        'name': list ('Ivone' for i in range(len(random_numbers)))
       #random_dic_update.get (i) :  df_descarga.loc[:, random_dic_update.get (i)] for i in random_numbers
    })

my_df_stocks.to_csv('my_portfolio.csv')

#save it as my_portfolio.pkl or my_portfolio.csv
